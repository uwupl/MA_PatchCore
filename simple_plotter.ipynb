# %%
from utils import plot_results, get_plot_ready_data

# %%
this_run_id = '1505_'
res_path = r'/mnt/crucial/UNI/IIIT_Muen/MA/code/productive/MA_PatchCore/results/'
to_contain = ['RN34_', '25_', 'layers_2']
to_contain += ['reduced_']
to_delete = ['layers_2_3_', 'layers_2_4_']#['reduced_entropy_normed_']
title =''#Comparison\nFIXED: Sigmoid, RN18, reduced via std (keep low); VARIABLE: Reduction ratio'
plot_results(
    *get_plot_ready_data(this_run_id, res_path, to_contain, to_delete),
    fig_size=(80,10),
    title=title, 
    only_auc=True,
    width=0.4,
    save_fig=True,
    res_path=res_path,
    show=True,
    )
# Out:
# file not found:  /mnt/crucial/UNI/IIIT_Muen/MA/code/productive/MA_PatchCore/results/1505__failed_runs.npy/csv/summary_1505__failed_runs.npy.csv
# /mnt/crucial/UNI/IIIT_Muen/MA/code/productive/MA_PatchCore/results/1505_with_ReLu_RN18_reduced_entropy_normed_25_layers_2/csv/summary_1505_with_ReLu_RN18_reduced_entropy_normed_25_layers_2.csv
# file not found:  /mnt/crucial/UNI/IIIT_Muen/MA/code/productive/MA_PatchCore/results/1505_with_ReLu_WRN50_reduced_entropy_100_layers_1_4/csv/summary_1505_with_ReLu_WRN50_reduced_entropy_100_layers_1_4.csv
# file not found:  /mnt/crucial/UNI/IIIT_Muen/MA/code/productive/MA_PatchCore/results/1505_with_ReLu_WRN50_reduced_entropy_100_layers_2_4/csv/summary_1505_with_ReLu_WRN50_reduced_entropy_100_layers_2_4.csv
# file not found:  /mnt/crucial/UNI/IIIT_Muen/MA/code/productive/MA_PatchCore/results/1505_with_ReLu_WRN50_reduced_entropy_normed_75_layers_2_4/csv/summary_1505_with_ReLu_WRN50_reduced_entropy_normed_75_layers_2_4.csv
# ...

# %%
this_run_id = '1505_'
res_path = r'/mnt/crucial/UNI/IIIT_Muen/MA/code/productive/MA_PatchCore/results/'
to_contain = []#'RN34_', '25_', 'layers_2']
# to_contain += ['reduced_']
to_delete = []#'layers_2_3_', 'layers_2_4_']#['reduced_entropy_normed_']
title =''#Comparison\nFIXED: Sigmoid, RN18, reduced via std (keep low); VARIABLE: Reduction ratio'
plot_results(
    *get_plot_ready_data(this_run_id, res_path, to_contain, to_delete, take_n_best=25),
    fig_size=(80,10),
    title=title, 
    only_auc=True,
    width=0.4,
    save_fig=True,
    res_path=res_path,
    show=True,
    )
# Out:
# file not found:  /mnt/crucial/UNI/IIIT_Muen/MA/code/productive/MA_PatchCore/results/1505__failed_runs.npy/csv/summary_1505__failed_runs.npy.csv
# /mnt/crucial/UNI/IIIT_Muen/MA/code/productive/MA_PatchCore/results/1505_with_ReLu_RN18_reduced_entropy_normed_25_layers_2/csv/summary_1505_with_ReLu_RN18_reduced_entropy_normed_25_layers_2.csv
# file not found:  /mnt/crucial/UNI/IIIT_Muen/MA/code/productive/MA_PatchCore/results/1505_with_ReLu_WRN50_reduced_entropy_100_layers_1_4/csv/summary_1505_with_ReLu_WRN50_reduced_entropy_100_layers_1_4.csv
# file not found:  /mnt/crucial/UNI/IIIT_Muen/MA/code/productive/MA_PatchCore/results/1505_with_ReLu_WRN50_reduced_entropy_100_layers_2_4/csv/summary_1505_with_ReLu_WRN50_reduced_entropy_100_layers_2_4.csv
# file not found:  /mnt/crucial/UNI/IIIT_Muen/MA/code/productive/MA_PatchCore/results/1505_with_ReLu_WRN50_reduced_entropy_normed_75_layers_2_4/csv/summary_1505_with_ReLu_WRN50_reduced_entropy_normed_75_layers_2_4.csv
# ...

# %%
a = np.arange(1, 10)

# %%
import numpy as np

# %%
a[-2:]
# Out:
# array([8, 9])
